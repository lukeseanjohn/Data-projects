# %% [markdown]
# Importing required packages to assist with data processing. 'Iris' dataset is pulled from seaborn

# %%
Import pandas as pd
import numpy as py
import matplotlib.pyplot as plt 
import seaborn

# %% [markdown]
# Loading dataset 'iris' into jupyter notebook and printing all columns

# %%
df = sns.load_dataset('iris')
print(df.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# Print first 5 rows of data

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Selecting different columns

# %%
species = df['species']
print(species)
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %% [markdown]
# Selecting multiple columns

# %%
multi = df[['sepal_length', 'sepal_width']]
print(multi)
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %% [markdown]
# Printing entire dataset

# %%
print(df.to_string())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %% [markdown]
# Using standard deviation function for specific column

# %%
print(df['sepal_length'].std())
# Out:
# 0.8280661279778629

# %% [markdown]
# Using mean function for specific column

# %%
print(df['sepal_width'].mean())
# Out:
# 5.843333333333334

# %% [markdown]
# Using variance function for specific column

# %%
print(df['petal_width'].var())
# Out:
# 0.5810062639821029

# %% [markdown]
# Filtering specific data from a specific column

# %%
Below_4 = df[df['petal_length']< 4]
print(Below_4)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 0            5.1          3.5           1.4          0.2      setosa
# 1            4.9          3.0           1.4          0.2      setosa
# 2            4.7          3.2           1.3          0.2      setosa
# 3            4.6          3.1           1.5          0.2      setosa
# 4            5.0          3.6           1.4          0.2      setosa
# ..           ...          ...           ...          ...         ...
# 80           5.5          2.4           3.8          1.1  versicolor
# 81           5.5          2.4           3.7          1.0  versicolor
# 82           5.8          2.7           3.9          1.2  versicolor
# 93           5.0          2.3           3.3          1.0  versicolor
# 98           5.1          2.5           3.0          1.1  versicolor
#
# [61 rows x 5 columns]

# %%
Above_4 = df[df['petal_length']> 4]
print(Above_4)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# 55            5.7          2.8           4.5          1.3  versicolor
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3   virginica
# 146           6.3          2.5           5.0          1.9   virginica
# 147           6.5          3.0           5.2          2.0   virginica
# 148           6.2          3.4           5.4          2.3   virginica
# 149           5.9          3.0           5.1          1.8   virginica
#
# [84 rows x 5 columns]

# %% [markdown]
# Extracting information to look for patterns in the data

# %%
between_2_and_4 = Below_4[Below_4['petal_length']< 2]
print(between_2_and_4)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %% [markdown]
# Using groupby function to acquire the average petal widths
# Can possibly construe analysis of the relationship between petal lengths and petal widths from the data below

# %%
petals = df.groupby('petal_length')['petal_width'].mean()
print(petals)
# Out:
# petal_length
# 1.0    0.200000
# 1.1    0.100000
# 1.2    0.200000
# 1.3    0.257143
# 1.4    0.207692
# 1.5    0.238462
# 1.6    0.285714
# 1.7    0.350000
# 1.9    0.300000
# 3.0    1.100000
# 3.3    1.000000
# 3.5    1.000000
# 3.6    1.300000
# 3.7    1.000000
# 3.8    1.100000
# 3.9    1.233333
# 4.0    1.220000
# 4.1    1.200000
# 4.2    1.325000
# 4.3    1.300000
# 4.4    1.325000
# 4.5    1.512500
# 4.6    1.400000
# 4.7    1.420000
# 4.8    1.700000
# 4.9    1.720000
# 5.0    1.775000
# 5.1    1.925000
# 5.2    2.150000
# 5.3    2.100000
# 5.4    2.200000
# 5.5    1.900000
# 5.6    2.050000
# 5.7    2.300000
# 5.8    1.866667
# 5.9    2.200000
# 6.0    2.150000
# 6.1    2.233333
# 6.3    1.800000
# 6.4    2.000000
# 6.6    2.100000
# 6.7    2.100000
# 6.9    2.300000
# Name: petal_width, dtype: float64

# %%
Sorting by ascending and descending values dependent on column chosen

# %%
size = df.sort_values(by='sepal_length',ascending=True)
print(size)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
size = df.sort_values(by='petal_length',ascending=False)
print(size)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 118           7.7          2.6           6.9          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# ..            ...          ...           ...          ...        ...
# 16            5.4          3.9           1.3          0.4     setosa
# 35            5.0          3.2           1.2          0.2     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 22            4.6          3.6           1.0          0.2     setosa
#
# [150 rows x 5 columns]

# %% [markdown]
# Selecting row range

# %%
row_selection = df[1:2]
print(row_selection)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 1           4.9          3.0           1.4          0.2  setosa

# %% [markdown]
# Selecing multi row range including last row

# %%
multirows = df.loc[50:60]
print(rows)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor

# %% [markdown]
# Selecting rows and columns using loc and iloc

# %%
rows_columns = df.iloc[5:10,[4,2]]
print(rows_columns)
# Out:
#   species  petal_length
# 5  setosa           1.7
# 6  setosa           1.4
# 7  setosa           1.5
# 8  setosa           1.4
# 9  setosa           1.5

# %%
columns_rows = df.loc[2:20,['sepal_width','petal_width', 'petal_length']]
print(columns_rows)
# Out:
#     sepal_width  petal_width  petal_length
# 2           3.2          0.2           1.3
# 3           3.1          0.2           1.5
# 4           3.6          0.2           1.4
# 5           3.9          0.4           1.7
# 6           3.4          0.3           1.4
# 7           3.4          0.2           1.5
# 8           2.9          0.2           1.4
# 9           3.1          0.1           1.5
# 10          3.7          0.2           1.5
# 11          3.4          0.2           1.6
# 12          3.0          0.1           1.4
# 13          3.0          0.1           1.1
# 14          4.0          0.2           1.2
# 15          4.4          0.4           1.5
# 16          3.9          0.4           1.3
# 17          3.5          0.3           1.4
# 18          3.8          0.3           1.7
# 19          3.8          0.3           1.5
# 20          3.4          0.2           1.7

# %%
Showing maximum and minimum length and widths

# %%
sizes = df['petal_width'].max()
print(sizes)
# Out:
# 2.5

# %%
sizes = df['sepal_length'].min()
print(sizes)
# Out:
# 4.3

# %% [markdown]
# Finding average sepal_length dependent on species

# %%
versicolor = df[df.species == "versicolor"].loc[:,"sepal_length"].mean()
print("The average sepal_length for versicolor species is:")
print(versicolor)
# Out:
# The average sepal_length for versicolor species is:
# 5.936

# %%
x = df.iloc[:,:0].values
y = df.iloc[:,:-1].values

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(data=df, x="sepal_length",hue="sepal_width", multiple="stack")
plt.xlabel('sepal_length')
plt.ylabel('petal_length')
plt.show()
# Out:
# C:\Users\Admin\Downloads\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4564\3287291367.py:2: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=df, x="sepal_length",hue="sepal_width", multiple="stack")

# %%
sns.pairplot(df,hue="sepal_width",diag_kind="kde")
plt.show()
# Out:
# C:\Users\Admin\Downloads\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\Downloads\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\Downloads\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
species = df.sort_values('species')
print(species)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 27            5.2          3.5           1.5          0.2     setosa
# 28            5.2          3.4           1.4          0.2     setosa
# 29            4.7          3.2           1.6          0.2     setosa
# 30            4.8          3.1           1.6          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 119           6.0          2.2           5.0          1.5  virginica
# 120           6.9          3.2           5.7          2.3  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
